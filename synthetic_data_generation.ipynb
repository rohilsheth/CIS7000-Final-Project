# %%
DISCHARGE_NOTE_FORMAT = """
Name:  ___                    Unit No:   ___
 
Admission Date:  ___              Discharge Date:   ___
 
Date of Birth:  ___             Sex:   ___
 
Service: ___

Allergies: 
___

Attending: ___.
 
Chief Complaint:
___

Major Surgical or Invasive Procedure:
___
 
History of Present Illness:
___
 
Past Medical History:
___
 
Social History:
___

Family History:
___

Physical Exam:
___
 
Pertinent Results:
At Admission:
___
At Discharge:
___
 
Brief Hospital Course:
___
 
Medications on Admission:
___
 
Discharge Medications:
___
 
Discharge Disposition:
___
 
Facility:
___
 
Discharge Diagnosis:
___
 
Discharge Condition:
Mental Status: Clear and coherent.
Level of Consciousness: Alert and interactive.
Activity Status: Ambulatory - Independent with walker
"""

# %%
PAST_MEDICAL_HISTORY_TYPES = {
    "Hypertension",
    "Diabetes mellitus",
    "Hyperlipidemia",
    "Coronary artery disease",
    "Atrial fibrillation",
    "Congestive heart failure",
    "Chronic kidney disease",
    "Chronic obstructive pulmonary disease",
    "Asthma",
    "Stroke",
    "Cancer",
    "Depression",
    "Anxiety",
    "Schizophrenia",
    "Bipolar disorder",
    "Alcohol abuse",
    "Drug abuse",
    "Smoking",
    "Obesity",
    "Edema",
    "Hypothyroidism",
    "Dementia",
    "Pneumonia",
}

# %%
from openai import ChatCompletion
from models import Complaint
from typing import List

COMPLAINT_SYSTEM_MESSAGE = """
You are SynthMedGPT, a bot that generates synthetic medical data. Your task today is to generate a list of possible complaints for a patient, as well as one ore more highly relevant procedures a doctor might initiate to address their complaint. Your outputs should be in the following format:

Complaint: [complaint] Procedures: [procedure1], [procedure2], [procedure3]
Complaint: [complaint] Procedures: [procedure1], [procedure2], [procedure3]
"""

COMPLAINT_PROMPT = """
Generate for me a list of 20 complaint-procedure pairs.
"""

def generate_complaint() -> List[Complaint]:
    response = ChatCompletion.create(
        model="gpt-4",
        messages=[
                {"role": "system", "content": COMPLAINT_SYSTEM_MESSAGE},
                {"role": "user", "content": COMPLAINT_PROMPT},
            ]
    )
    print(response.choices[0]["message"]["content"])

generate_complaint()
# Out:
# Complaint: Chest pain Procedures: Electrocardiogram (ECG), chest X-ray, cardiac stress test
# Complaint: Shortness of breath Procedures: Pulmonary function test, chest X-ray, arterial blood gas analysis
# Complaint: Persistent cough Procedures: Chest X-ray, sputum culture, spirometry
# Complaint: Abdominal pain Procedures: Abdominal ultrasound, CT scan, endoscopy
# Complaint: Headache Procedures: MRI, CT scan, lumbar puncture
# Complaint: Joint pain Procedures: X-ray, joint aspiration, magnetic resonance imaging (MRI)
# Complaint: Fever Procedures: Blood culture, urine culture, chest X-ray
# Complaint: Dizziness Procedures: Electronystagmography (ENG), blood pressure monitoring, audiometry
# Complaint: Swollen lymph nodes Procedures: Fine needle aspiration (FNA), biopsy, ultrasound
# Complaint: Fatigue Procedures: Blood tests, sleep study, electrocardiogram (ECG)
# Complaint: Weight loss Procedures: Blood tests, abdominal ultrasound, endoscopy
# Complaint: Nausea and vomiting Procedures: Blood tests, abdominal X-ray, gastroscopy
# Complaint: Low back pain Procedures: X-ray, MRI, bone scan
# Complaint: Constipation Procedures: Rectal exam, blood tests, colonoscopy
# Complaint: Irregular heartbeat Procedures: Electrocardiogram (ECG), Holter monitor, echocardiogram
# Complaint: Frequent urination Procedures: Urinalysis, blood glucose test, ultrasound
# Complaint: Skin rash Procedures: Skin biopsy, allergy testing, blood tests
# Complaint: Sore throat Procedures: Throat swab, rapid antigen test, throat culture
# Complaint: Diarrhea Procedures: Stool culture, blood tests, colonoscopy
# Complaint: Elevated blood pressure Procedures: Blood pressure monitoring, blood tests, urine tests
